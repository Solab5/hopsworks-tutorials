# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#1EB182;"><img src="../../images/icon102.png" width="38px"></img> **Hopsworks Feature Store** </span>
#
# <span style="font-width:bold; font-size: 3rem; color:#333;">- Part 01: Feature Backfill</span>
#
# **Note**: This tutorial does not support Google Colab.
#
# ## 🗒️ This notebook is divided into the following sections:
#
# 1. Fetch historical data.
# 2. Connect to the Hopsworks feature store.
# 3. Create feature groups and insert them to the feature store.
#
# ![tutorial-flow](../../images/01_featuregroups.png)

# %% [markdown]
# ## <span style='color:#ff5f27'> 📝 Imports

# %%
# !pip install -r requirements.txt --quiet
# !pip install -U hopsworks --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.3.3 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# google-api-core 2.12.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# googleapis-common-protos 1.61.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# grpcio-status 1.59.0 requires protobuf>=4.21.6, but you have protobuf 3.20.0 which is incompatible.
# onnx 1.14.1 requires protobuf>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x102c324d0>, 'Connection to files.pythonhosted.org timed out. (connect timeout=15)')': /packages/8b/5e/d075fb7d93d757da5601d55188bde9869a9a6b59b1fc8d7fb0fdce7714a2/pyhumps-1.6.1-py3-none-any.whl.metadata
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 3.0.2 requires Jinja2>=3.1.2, but you have jinja2 3.0.3 which is incompatible.
# litellm 1.20.1 requires jinja2<4.0.0,>=3.1.2, but you have jinja2 3.0.3 which is incompatible.
# werkzeug 3.0.1 requires MarkupSafe>=2.1.1, but you have markupsafe 2.0.1 which is incompatible.

# %%
# !pip install folium
# Out:
# Collecting folium
#   Obtaining dependency information for folium from https://files.pythonhosted.org/packages/b9/98/9ba4b9d2d07dd32765ddb4e4c189dcbdd7dca4d5a735e2e4ea756f40c36b/folium-0.16.0-py2.py3-none-any.whl.metadata
#   Downloading folium-0.16.0-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting branca>=0.6.0 (from folium)
#   Obtaining dependency information for branca>=0.6.0 from https://files.pythonhosted.org/packages/17/ce/14166d0e273d12065516625fb02426350298e7b4ba59198b5fe454b46202/branca-0.7.1-py3-none-any.whl.metadata
#   Downloading branca-0.7.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in /Users/rtv-lpt-127/mambaforge/lib/python3.10/site-packages (from folium) (3.0.3)
# Requirement already satisfied: numpy in /Users/rtv-lpt-127/mambaforge/lib/python3.10/site-packages (from folium) (1.26.0)
# Requirement already satisfied: requests in /Users/rtv-lpt-127/mambaforge/lib/python3.10/site-packages (from folium) (2.31.0)
# Collecting xyzservices (from folium)
#   Obtaining dependency information for xyzservices from https://files.pythonhosted.org/packages/82/c3/e06dfa46464cce3eda4b86df8847cab99d9bc545c76807ee689545187a4c/xyzservices-2023.10.1-py3-none-any.whl.metadata
#   Downloading xyzservices-2023.10.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rtv-lpt-127/mambaforge/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rtv-lpt-127/mambaforge/lib/python3.10/site-packages (from requests->folium) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rtv-lpt-127/mambaforge/lib/python3.10/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rtv-lpt-127/mambaforge/lib/python3.10/site-packages (from requests->folium) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rtv-lpt-127/mambaforge/lib/python3.10/site-packages (from requests->folium) (2023.7.22)
# Using cached folium-0.16.0-py2.py3-none-any.whl (100 kB)
# Using cached branca-0.7.1-py3-none-any.whl (25 kB)
# Using cached xyzservices-2023.10.1-py3-none-any.whl (56 kB)
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.7.1 folium-0.16.0 xyzservices-2023.10.1

# %%
import json

import pandas as pd
import folium

from features import air_quality
from functions.common_functions import convert_date_to_unix

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## <span style='color:#ff5f27'> 🌍 Representing the Target cities </span>

# %%
Latitude	0.347596
Longitude	32.582520

# %%
Latitude	-0.607160
Longitude	30.654503

# %%
gulu
Latitude:2.830556; 
Longitude:32.320278

# %%
# Open the 'target_cities.json' file in read mode
with open('target_cities.json') as json_file:
    # Load the JSON data from the file into a Python dictionary
    target_cities = json.load(json_file)

# Now, 'target_cities' contains the data from the JSON file

# %%
new_locations = {
    "AFRICA": {
        "Mbarara": [-0.607160, 30.654503],
        "Kampala": [0.347596, 32.582520],
        "Gulu": [2.830556, -32.320278]
    }
}

# %%
for continent, locations in new_locations.items():
    target_cities[continent] = locations

# %%
target_cities
# Out:
# {'EU': {'Amsterdam': [52.37, 4.89],
#   'Athina': [37.98, 23.73],
#   'Berlin': [52.52, 13.39],
#   'Gdansk': [54.37, 18.61],
#   'Kraków': [50.06, 19.94],
#   'London': [51.51, -0.13],
#   'Madrid': [40.42, -3.7],
#   'Marseille': [43.3, 5.37],
#   'Milano': [45.46, 9.19],
#   'München': [48.14, 11.58],
#   'Napoli': [40.84, 14.25],
#   'Paris': [48.85, 2.35],
#   'Sevilla': [37.39, -6.0],
#   'Stockholm': [59.33, 18.07],
#   'Tallinn': [59.44, 24.75],
#   'Varna': [43.21, 27.92],
#   'Wien': [48.21, 16.37]},
#  'US': {'Albuquerque': [35.08, -106.65],
#   'Atlanta': [33.75, -84.39],
#   'Chicago': [41.88, -87.62],
#   'Columbus': [39.96, -83.0],
#   'Dallas': [32.78, -96.8],
#   'Denver': [39.74, -104.98],
#   'Houston': [29.76, -95.37],
#   'Los Angeles': [34.05, -118.24],
#   'New York': [40.71, -74.01],
#   'Phoenix-Mesa': [33.66, -112.04],
#   'Salt Lake City': [40.76, -111.89],
#   'San Francisco': [37.78, -122.42],
#   'Tampa': [27.95, -82.46]},
#  'Seattle': {'Bellevue-SE 12th St': [47.60086, -122.1484],
#   'DARRINGTON - FIR ST (Darrington High School)': [48.2469, -121.6031],
#   'KENT - JAMES & CENTRAL': [47.38611, -122.23028],
#   'LAKE FOREST PARK TOWNE CENTER': [47.755, -122.2806],
#   'MARYSVILLE - 7TH AVE (Marysville Junior High)': [48.05432, -122.17153],
#   'NORTH BEND - NORTH BEND WAY': [47.49022, -121.77278],
#   'SEATTLE - BEACON HILL': [47.56824, -122.30863],
#   'SEATTLE - DUWAMISH': [47.55975, -122.33827],
#   'SEATTLE - SOUTH PARK #2': [47.53091, -122.3208],
#   'Seattle-10th & Weller': [47.59722, -122.31972],
#   'TACOMA - ALEXANDER AVE': [47.2656, -122.3858],
#   'TACOMA - L STREET': [47.1864, -122.4517],
#   'Tacoma-S 36th St': [47.22634, -122.46256],
#   'Tukwila Allentown': [47.49854, -122.27839],
#   'Tulalip-Totem Beach Rd': [48.06534, -122.28519]},
#  'AFRICA': {'Mbarara': [-0.60716, 30.654503],
#   'Kampala': [0.347596, 32.58252],
#   'Gulu': [2.830556, -32.320278]}}

# %%
# Create a folium map centered on the first location in the list
my_map = folium.Map(location=[42.57, -44.092], zoom_start=3)

for continent in target_cities:
        for city_name, coords in target_cities[continent].items():
            folium.CircleMarker(
                location=coords,
                popup=city_name,
            ).add_to(my_map)
#my_map

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cf688f10454f25ebcc758b10ca5d617 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cf688f10454f25ebcc758b10ca5d617&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cf688f10454f25ebcc758b10ca5d617 = L.map(
#                 &quot;map_3cf688f10454f25ebcc758b10ca5d617&quot;,
#                 {
#                     center: [42.57, -44.092],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_908f6ebcdfc0ba2cc754ae21a8e819ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_908f6ebcdfc0ba2cc754ae21a8e819ea.addTo(map_3cf688f10454f25ebcc758b10ca5d617);
#
#
#             var circle_marker_d1744087ebc37f0b2110e3ea0b01b5a0 = L.circleMarker(
#                 [52.37, 4.89],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3cf688f10454f25ebcc758b10ca5d617);
#
#
#         var popup_e1978ddc79055e0067509f6b6707f70d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_051a487dfb36b1ea4c461272a59844c0 = $(`&lt;div id=&quot;html_051a487dfb36b1ea4c461272a59844c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Amsterdam&lt;/div&gt;`)[0];
#                 popup_e1978ddc79055e0067509f6b6707f70d.setContent(html_051a487dfb36b1ea4c461272a59844c0);
#
#
#
#         circle_marker_d1744087ebc37f0b2110e3ea0b01b5a0.bindPopup(popup_e1978ddc79055e0067509f6b6707f70d)
#         ;
#
#
#
#
#             var circle_marker_0042cd40bbbb9599bf1399505dabaeb5 = L.circleMarker(
#                 [37.98, 23.73],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3cf688f10454f25ebcc758b10ca5d617);
#
#
#         var popup_383f6f50dc4f436cbdd89f4ce281e751 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_79b6566b992ebef17247ea94427be047 = $(`&lt;div id=&quot;html_79b6566b992ebef17247ea94427be047&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Athina&lt;/div&gt;`)[0];
#                 popup_383f6f50dc4f436cbdd89f4ce281e751.setContent(html_79b6566b992ebef17247ea94427be047);
#
#
#
#         circle_marker_0042cd40bbbb9599bf1399505dabaeb5.bindPopup(popup_383f6f50dc4f436cbdd89f4ce281e751)
#         ;
#
#
#
#
#             var circle_marker_7d1290631984a52ac31b620fcbb67bef = L.circleMarker(
#                 [52.52, 13.39],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3cf688f10454f25ebcc758b10ca5d617);
#
#
#         var popup_264a0fd2a9821590dffb038583f2b68d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a0d108a39482a5ab4ac6b5005581679 = $(`&lt;div id=&quot;html_6a0d108a39482a5ab4ac6b5005581679&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_264a0fd2a9821590dffb038583f2b68d.setContent(html_6a0d108a39482a5ab4ac6b5005581679);
#
#
#
#         circle_marker_7d1290631984a52ac31b620fcbb67bef.bindPopup(popup_264a0fd2a9821590dffb038583f2b68d)
#         ;
#
#
#
#
#             var circle_marker_50999c3dea0504c4ff3fecfb8cbfe71c = L.circleMarker(
#                 [54.37, 18.61],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &qu

# %%
# # Save the map to an HTML file
# my_map.save("map_all_target_cities.html")

# %% [markdown]
# ## <span style='color:#ff5f27'> 🌫 Processing Air Quality data</span>

# %% [markdown]
# ### [🇪🇺 EEA](https://discomap.eea.europa.eu/map/fme/AirQualityExport.htm)
# #### EEA means European Environmental Agency

# %%
# EU Cities 
target_cities["EU"]
# Out:
# {'Amsterdam': [52.37, 4.89],
#  'Athina': [37.98, 23.73],
#  'Berlin': [52.52, 13.39],
#  'Gdansk': [54.37, 18.61],
#  'Kraków': [50.06, 19.94],
#  'London': [51.51, -0.13],
#  'Madrid': [40.42, -3.7],
#  'Marseille': [43.3, 5.37],
#  'Milano': [45.46, 9.19],
#  'München': [48.14, 11.58],
#  'Napoli': [40.84, 14.25],
#  'Paris': [48.85, 2.35],
#  'Sevilla': [37.39, -6.0],
#  'Stockholm': [59.33, 18.07],
#  'Tallinn': [59.44, 24.75],
#  'Varna': [43.21, 27.92],
#  'Wien': [48.21, 16.37]}

# %%
# Read the CSV file from the specified URL into a pandas DataFrame
df_eu = pd.read_csv("https://repo.hops.works/dev/davit/air_quality/backfill_pm2_5_eu.csv")

# Print the size of the 'df_eu' DataFrame (number of rows and columns)
print("⛳️ Size of this dataframe:", df_eu.shape)

# Check for missing values in the 'df_eu' DataFrame
print(f'⛳️ Missing Values: {df_eu.isna().sum().sum()}')

# Display a random sample of three rows from the 'df_eu' DataFrame
df_eu.sample(3)
# Out:
# ⛳️ Size of this dataframe: (63548, 3)
# ⛳️ Missing Values: 0
#       city_name        date  pm2_5
# 21048    London  2019-04-03   11.0
# 5671     Athina  2018-04-03   17.0
# 58499     Varna  2019-01-15    9.0

# %% [markdown]
# ### [🇺🇸 USEPA](https://aqs.epa.gov/aqsweb/documents/data_api.html#daily)
# #### USEPA means United States Environmental Protection Agency
# [Manual downloading](https://www.epa.gov/outdoor-air-quality-data/download-daily-data)

# %%
# US Cities 
target_cities["US"]
# Out:
# {'Albuquerque': [35.08, -106.65],
#  'Atlanta': [33.75, -84.39],
#  'Chicago': [41.88, -87.62],
#  'Columbus': [39.96, -83.0],
#  'Dallas': [32.78, -96.8],
#  'Denver': [39.74, -104.98],
#  'Houston': [29.76, -95.37],
#  'Los Angeles': [34.05, -118.24],
#  'New York': [40.71, -74.01],
#  'Phoenix-Mesa': [33.66, -112.04],
#  'Salt Lake City': [40.76, -111.89],
#  'San Francisco': [37.78, -122.42],
#  'Tampa': [27.95, -82.46]}

# %%
# Read the CSV file from the specified URL into a pandas DataFrame
df_us = pd.read_csv("https://repo.hops.works/dev/davit/air_quality/backfill_pm2_5_us.csv")

# Print the size of the 'df_us' DataFrame (number of rows and columns)
print("⛳️ Size of this dataframe:", df_us.shape)

# Check for missing values in the 'df_us' DataFrame
print(f'⛳️ Missing Values: {df_us.isna().sum().sum()}')

# Display a random sample of three rows from the 'df_us' DataFrame
df_us.sample(3)
# Out:
# ⛳️ Size of this dataframe: (46037, 3)
# ⛳️ Missing Values: 0
#              date     city_name  pm2_5
# 13568  2013-05-13        Dallas    9.2
# 32468  2015-09-28  Phoenix-Mesa    8.6
# 8850   2017-04-07       Chicago    3.4

# %% [markdown]
# ### <span style="color:#ff5f27;">🏢 Processing special city - `Seattle`</span>
# #### We need different stations across the Seattle.
# I downloaded daily `PM2.5` data manually [here](https://www.epa.gov/outdoor-air-quality-data/download-daily-data)

# %%
target_cities["Seattle"]
# Out:
# {'Bellevue-SE 12th St': [47.60086, -122.1484],
#  'DARRINGTON - FIR ST (Darrington High School)': [48.2469, -121.6031],
#  'KENT - JAMES & CENTRAL': [47.38611, -122.23028],
#  'LAKE FOREST PARK TOWNE CENTER': [47.755, -122.2806],
#  'MARYSVILLE - 7TH AVE (Marysville Junior High)': [48.05432, -122.17153],
#  'NORTH BEND - NORTH BEND WAY': [47.49022, -121.77278],
#  'SEATTLE - BEACON HILL': [47.56824, -122.30863],
#  'SEATTLE - DUWAMISH': [47.55975, -122.33827],
#  'SEATTLE - SOUTH PARK #2': [47.53091, -122.3208],
#  'Seattle-10th & Weller': [47.59722, -122.31972],
#  'TACOMA - ALEXANDER AVE': [47.2656, -122.3858],
#  'TACOMA - L STREET': [47.1864, -122.4517],
#  'Tacoma-S 36th St': [47.22634, -122.46256],
#  'Tukwila Allentown': [47.49854, -122.27839],
#  'Tulalip-Totem Beach Rd': [48.06534, -122.28519]}

# %%
# Read the CSV file from the specified URL into a pandas DataFrame
df_seattle = pd.read_csv("https://repo.hops.works/dev/davit/air_quality/backfill_pm2_5_seattle.csv")

# Print the size of the 'df_seattle' DataFrame (number of rows and columns)
print("⛳️ Size of this dataframe:", df_seattle.shape)

# Check for missing values in the 'df_seattle' DataFrame
print(f'⛳️ Missing Values: {df_seattle.isna().sum().sum()}')

# Display a random sample of three rows
df_seattle.sample(3)
# Out:
# ⛳️ Size of this dataframe: (46479, 3)
# ⛳️ Missing Values: 0
#                          city_name        date  pm2_5
# 37954             Tacoma-S 36th St  2021-11-09    5.5
# 34536  NORTH BEND - NORTH BEND WAY  2021-05-24    0.8
# 36694        SEATTLE - BEACON HILL  2021-01-09    3.7

# %% [markdown]
# ### <span style="color:#ff5f27;">🌟 All together</span>

# %%
# Concatenate the DataFrames df_eu, df_us, and df_seattle along the rows and reset the index
df_air_quality = pd.concat(
    [df_eu, df_us, df_seattle],
).reset_index(drop=True)

# Print the shape of the df_air_quality DataFrame
print(f'⛳️ DF shape: {df_air_quality.shape}')

# Display a random sample of five rows from the df_air_quality DataFrame
df_air_quality.sample(5)
# Out:
# ⛳️ DF shape: (156064, 3)
#                      city_name        date  pm2_5
# 91086              Los Angeles  2022-03-29    5.2
# 112398  TACOMA - ALEXANDER AVE  2013-11-14    7.5
# 106454                   Tampa  2014-05-28    9.3
# 118297   SEATTLE - BEACON HILL  2015-11-14    2.9
# 57053                    Varna  2015-01-30    7.0

# %% [markdown]
# ## <span style="color:#ff5f27;">🛠 Feature Engineering</span>

# %%
# Convert the 'date' column in the df_air_quality DataFrame to datetime format
df_air_quality['date'] = pd.to_datetime(df_air_quality['date'])

# %%
# Apply feature engineering to the df_air_quality DataFrame using the air_quality.feature_engineer_aq() function
df_air_quality = air_quality.feature_engineer_aq(df_air_quality)

# Drop rows with missing values in the df_air_quality DataFrame
df_air_quality = df_air_quality.dropna()

# Check and print the total number of missing values in the df_air_quality DataFrame
df_air_quality.isna().sum().sum()
# Out:
# 0

# %%
# Print the shape (number of rows and columns) of the df_air_quality DataFrame
df_air_quality.shape
# Out:
# (154804, 31)

# %%
# Retrieve and display the column names of the df_air_quality DataFrame
df_air_quality.columns
# Out:
# Index(['city_name', 'date', 'pm2_5', 'pm_2_5_previous_1_day',
#        'pm_2_5_previous_2_day', 'pm_2_5_previous_3_day',
#        'pm_2_5_previous_4_day', 'pm_2_5_previous_5_day',
#        'pm_2_5_previous_6_day', 'pm_2_5_previous_7_day', 'mean_7_days',
#        'mean_14_days', 'mean_28_days', 'std_7_days', 'exp_mean_7_days',
#        'exp_std_7_days', 'std_14_days', 'exp_mean_14_days', 'exp_std_14_days',
#        'std_28_days', 'exp_mean_28_days', 'exp_std_28_days', 'year',
#        'day_of_month', 'month', 'day_of_week', 'is_weekend', 'sin_day_of_year',
#        'cos_day_of_year', 'sin_day_of_week', 'cos_day_of_week'],
#       dtype='object')

# %% [markdown]
# ## <span style='color:#ff5f27'> 🌦 Loading Weather Data from [Open Meteo](https://open-meteo.com/en/docs)

# %%
# Read the CSV file from the specified URL into a pandas DataFrame for weather data
df_weather = pd.read_csv("https://repo.hops.works/dev/davit/air_quality/backfill_weather.csv")

# Display the first three rows of the df_weather DataFrame
df_weather.head(3)
# Out:
#    city_name        date  temperature_max  temperature_min  precipitation_sum  \
# 0  Amsterdam  2013-01-01              9.2              5.5               10.2
# 1  Amsterdam  2013-01-02              7.8              5.6                0.5
# 2  Amsterdam  2013-01-03             10.3              8.2                2.0
#
#    rain_sum  snowfall_sum  precipitation_hours  wind_speed_max  \
# 0      10.2           0.0                 14.0            32.0
# 1       0.5           0.0                  2.0            22.9
# 2       2.0           0.0                  6.0            22.2
#
#    wind_gusts_max  wind_direction_dominant
# 0            62.6                      255
# 1            39.6                      251
# 2            39.2                      255

# %% [markdown]
# ---

# %%
# Apply the 'convert_date_to_unix' function to create a new 'unix_time' column in df_air_quality
df_air_quality["unix_time"] = pd.to_datetime(df_air_quality.date).apply(convert_date_to_unix)

# Apply the 'convert_date_to_unix' function to create a new 'unix_time' column in df_weather
df_weather["unix_time"] = pd.to_datetime(df_weather.date).apply(convert_date_to_unix)

# Convert the 'date' column in the df_air_quality DataFrame back to string format
df_air_quality.date = df_air_quality.date.astype(str)

# Convert the 'date' column in the df_weather DataFrame back to string format
df_weather.date = df_weather.date.astype(str)

# %% [markdown]
# ## <span style="color:#ff5f27;"> 🔮 Connecting to Hopsworks Feature Store </span>

# %%
import hopsworks

project = hopsworks.login()

fs = project.get_feature_store()
# Out:
# Copy your Api Key (first register/login): https://c.app.hopsworks.ai/account/api/generated
# Paste it here:  ········
# Connected. Call `.close()` to terminate connection gracefully.
#
# Multiple projects found.
#
# 	 (1) Iriss_solab
# 	 (2) soll
# Enter project to access:  2
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/22689
# Connected. Call `.close()` to terminate connection gracefully.

# %% [markdown]
# ## <span style="color:#ff5f27;">🪄 Creating Feature Groups</span>

# %% [markdown]
# ### <span style='color:#ff5f27'> 🌫 Air Quality Data

# %%
# Get or create feature group
air_quality_fg = fs.get_or_create_feature_group(
    name='air_quality',
    description='Air Quality characteristics of each day',
    version=1,
    primary_key=['unix_time','city_name'],
    event_time=["unix_time"],
)   
# Insert data
air_quality_fg.insert(df_air_quality)
# Out:
# DeprecationWarning: Providing event_time as a single-element list is deprecated and will be dropped in future versions. Provide the feature_name string instead.
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/22689/fs/22609/fg/639312
# Uploading Dataframe: 0.00% |          | Rows 0/154804 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: air_quality_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/22689/jobs/named/air_quality_1_offline_fg_materialization/executions
# (<hsfs.core.job.Job at 0x111c7eb30>, None)

# %% [markdown]
# ### <span style='color:#ff5f27'> 🌦 Weather Data

# %%
# Get or create feature group
weather_fg = fs.get_or_create_feature_group(
    name='weather',
    description='Weather characteristics of each day',
    version=1,
    primary_key=['unix_time','city_name'],
    event_time=["unix_time"],
) 
# Insert data
weather_fg.insert(df_weather)
# Out:
# DeprecationWarning: Providing event_time as a single-element list is deprecated and will be dropped in future versions. Provide the feature_name string instead.
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/22689/fs/22609/fg/637294
# Uploading Dataframe: 0.00% |          | Rows 0/168975 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: weather_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/22689/jobs/named/weather_1_offline_fg_materialization/executions
# (<hsfs.core.job.Job at 0x111cd1690>, None)

# %% [markdown]
# ---
# ## <span style="color:#ff5f27;">⏭️ **Next:** Part 02: Feature Pipeline
#  </span>
#
# In the following notebook you will parse data and insert it into Feature Groups.
